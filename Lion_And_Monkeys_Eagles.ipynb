# %% [markdown]
# ## Aluno: Victor Macaúbas

# %% [markdown]
# # Pré processamento de dados
#
# Utilizei um dataset de imagens baixadas do google. e em seguida faremos a divisão em dois sets: um de treino e um para a validação.
#
# Para a criação do dataset utilizei o repositório do github "https://github.com/RiddlerQ/simple_image_download"
#
# Abaixo seguimos com a preparação dos dados.

# %%
# !rm -rf lions-and-monkeys-eagles/ val/ AnimalImages/ AnimalImagesAnimalImages/ AnimalImages/

# %% [markdown]
# ## Clonando meu repositório onde encontra-se as imagens

# %%
# !git clone https://github.com/victormacaubas/RedesNeurais.git
# Out:
# Cloning into 'RedesNeurais'...
# remote: Enumerating objects: 271, done.
# remote: Counting objects: 100% (271/271), done.
# remote: Compressing objects: 100% (261/261), done.
# remote: Total 271 (delta 21), reused 255 (delta 9), pack-reused 0
# Receiving objects: 100% (271/271), 175.40 MiB | 28.23 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# Checking out files: 100% (1341/1341), done.

# %% [markdown]
# # Criando os diretórios para a organização das imagens
#
# Aqui as imagens serão adicionadas na pasta 'train' para o treinamento do modelo

# %%
import os
import shutil
import re

base_dir = "AnimalImages"
try:
    os.makedirs("AnimalImages")
except OSError:
    print ("Creation of the directory %s failed")
else:
    print ("Successfully created the directory %s ")
dataset_dir = "RedesNeurais/test"


files = os.listdir(base_dir)


def train_maker(name):
  try:
      path = f"{base_dir}/train/{name}"
      os.makedirs(path, exist_ok=True)
  except OSError:
      print ("Creation of the directory failed")
  else:
      print ("Successfully created the directory")
  print("here")
  train_dir = f"{base_dir}/train/{name}"
  print(train_dir)
  files = os.listdir(dataset_dir)
  print(files)
  
  for f in files:
        search_object = re.search(name.lower(), f)
        print(search_object)
        if search_object:
          shutil.move(f'{dataset_dir}/{f}', train_dir)

train_maker("Lion")
train_maker("Monkey")
train_maker("Eagle")
# Out:
# Successfully created the directory %s
# Successfully created the directory
# here
# AnimalImages/train/Lion
# ...

# %% [markdown]
# ## Pastas de validção

# %%
try:
    path = base_dir + "/val/Lion"
    os.makedirs(path, exist_ok=True)
    path = base_dir + "/val/Monkey"
    os.makedirs(path, exist_ok=True)
    path = base_dir + "/val/Eagle"
    os.makedirs(path, exist_ok=True)
except OSError:
    print ("Creation of the directory failed")
else:
    print ("Successfully created the directory")
# Out:
# Successfully created the directory

# %%
lion_train = base_dir + "/train/Lion"
lion_val = base_dir + "/val/Lion/"
monkey_train = base_dir + "/train/Monkey/"
monkey_val = base_dir + "/val/Monkey/"
eagle_train = base_dir + "/train/Eagle/"
eagle_val = base_dir + "/val/Eagle/"

lion_files = os.listdir(lion_train)
monkey_files = os.listdir(monkey_train)
eagle_files = os.listdir(eagle_train)

# %%
print(eagle_files)
# Out:
# ['eagle_350.jpg', 'eagle_442.jpg', 'eagle_462.jpg', 'eagle_71.jpg', 'eagle_134.jpg', 'eagle_359.jpg', 'eagle_154.jpg', 'eagle_452.jpg', 'eagle_101.jpg', 'eagle_176.jpg', 'eagle_171.jpg', 'eagle_458.jpg', 'eagle_179.jpg', 'eagle_55.jpg', 'eagle_143.jpg', 'eagle_481.jpg', 'eagle_232.jpg', 'eagle_465.jpg', 'eagle_367.jpg', 'eagle_294.jpg', 'eagle_132.jpg', 'eagle_388.jpg', 'eagle_27.jpg', 'eagle_273.jpg', 'eagle_45.jpg', 'eagle_112.jpg', 'eagle_405.jpg', 'eagle_159.jpg', 'eagle_426.jpg', 'eagle_133.jpg', 'eagle_218.jpg', 'eagle_22.jpg', 'eagle_124.jpg', 'eagle_57.jpg', 'eagle_292.jpg', 'eagle_187.jpg', 'eagle_89.jpg', 'eagle_434.jpg', 'eagle_265.jpg', 'eagle_479.jpg', 'eagle_230.jpg', 'eagle_103.jpg', 'eagle_376.jpg', 'eagle_180.jpg', 'eagle_233.jpg', 'eagle_251.jpg', 'eagle_362.jpg', 'eagle_436.jpg', 'eagle_421.jpg', 'eagle_449.jpg', 'eagle_127.jpg', 'eagle_407.jpg', 'eagle_210.jpg', 'eagle_444.jpg', 'eagle_348.jpg', 'eagle_123.jpg', 'eagle_6.jpg', 'eagle_110.jpg', 'eagle_223.jpg', 'ea
# ...

# %% [markdown]
# ## Aqui colocamos as imagens da pasta de treinamento em suas respectivas pastas de validação

# %%
for f in lion_files:
    validationLionSearchObj = re.search("\d\d\d", f)
    if validationLionSearchObj:
        shutil.move(f'{lion_train}/{f}', lion_val)

for f in monkey_files:
    validationLionSearchObj = re.search("\d\d\d", f)
    if validationLionSearchObj:
        shutil.move(f'{monkey_train}/{f}', monkey_val)

for f in eagle_files:
    validationLionSearchObj = re.search("\d\d\d", f)
    if validationLionSearchObj:
        shutil.move(f'{eagle_train}/{f}', eagle_val)

# %%
# !ls AnimalImages//val/Eagle/
# Out:
# eagle_100.jpg  eagle_155.jpg  eagle_236.jpg  eagle_370.jpg  eagle_431.jpg
# eagle_101.jpg  eagle_156.jpg  eagle_237.jpg  eagle_371.jpg  eagle_432.jpg
# eagle_102.jpg  eagle_159.jpg  eagle_238.jpg  eagle_373.jpg  eagle_433.jpg
# eagle_103.jpg  eagle_161.jpg  eagle_241.jpg  eagle_374.jpg  eagle_434.jpg
# eagle_104.jpg  eagle_162.jpg  eagle_243.jpg  eagle_375.jpg  eagle_436.jpg
# eagle_105.jpg  eagle_163.jpg  eagle_244.jpg  eagle_376.jpg  eagle_437.jpg
# eagle_106.jpg  eagle_169.jpg  eagle_245.jpg  eagle_377.jpg  eagle_438.jpg
# eagle_108.jpg  eagle_170.jpg  eagle_251.jpg  eagle_378.jpg  eagle_440.jpg
# eagle_109.jpg  eagle_171.jpg  eagle_252.jpg  eagle_379.jpg  eagle_441.jpg
# eagle_110.jpg  eagle_173.jpg  eagle_253.jpg  eagle_380.jpg  eagle_442.jpg
# eagle_112.jpg  eagle_175.jpg  eagle_255.jpg  eagle_382.jpg  eagle_443.jpg
# eagle_113.jpg  eagle_176.jpg  eagle_257.jpg  eagle_383.jpg  eagle_444.jpg
# eagle_114.jpg  eagle_177.jpg  eagle_258.jpg  eagle_384.jpg  eagle_445.jpg
# ...

# %% [markdown]
# # Carrendo os dados
#
# Após a preparação dos dados, importei as libs.
# pyTorch, numpy e o matplotlib. Está última utilizaremos para a visualização de algumas das nossas imagens.

# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import numpy as np
import time
import os
import copy

# %% [markdown]
# Aqui carreguei os dados de treinamento e os preparei para serem utilizados pela rede neural. Usei o pytorch para manipular as imagens como por exemplo: As imagens no set de treinamento tem que ter o mesmo tamanho das imagens no set de validação.

# %%
mean_nums = [0.485, 0.456, 0.406]
std_nums = [0.229, 0.224, 0.225]

chosen_transforms = {'train': transforms.Compose([
        transforms.RandomResizedCrop(size=256),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean_nums, std_nums)
]), 'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean_nums, std_nums)
]),
}

# %% [markdown]
# Utilizando a função ImageFolder do PyTorch para a criação dos datasets

# %%
data_dir = 'AnimalImages/'

chosen_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), chosen_transforms[x]) for x in ['train', 'val']}

# %%
chosen_datasets
# Out:
# {'train': Dataset ImageFolder
#      Number of datapoints: 235
#      Root location: AnimalImages/train
#      StandardTransform
#  Transform: Compose(
#                 RandomResizedCrop(size=(256, 256), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear)
#                 RandomRotation(degrees=[-15.0, 15.0], interpolation=nearest, expand=False, fill=0)
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#                 Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#             ), 'val': Dataset ImageFolder
#      Number of datapoints: 763
#      Root location: AnimalImages/val
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=256, interpolation=bilinear, max_size=None, antialias=None)
#                 CenterCrop(size=(224, 224))
#                 ToTensor()
#                 Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#             )}

# %% [markdown]
# Usando DataLoader para a criação de objetos iteráveis

# %%
dataloaders = {x: torch.utils.data.DataLoader(chosen_datasets[x], batch_size=4,
  shuffle=True, num_workers=4)
              for x in ['train', 'val']}
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
dataloaders
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader at 0x7f2300922750>,
#  'val': <torch.utils.data.dataloader.DataLoader at 0x7f2300922890>}

# %% [markdown]
# Aqui especifiquei o uso da GPU se disponível, e preservamos algumas informações sobre nosso dataset, como o nome das classes.

# %%
dataset_sizes = {x: len(chosen_datasets[x]) for x in ['train', 'val']}
class_names = chosen_datasets['train'].classes

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(dataset_sizes)
print(class_names)
# Out:
# {'train': 235, 'val': 763}
# ['Eagle', 'Lion', 'Monkey']

# %% [markdown]
# Visualizando algumas imagens com uma função

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([mean_nums])
    std = np.array([std_nums])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %%
inputs, classes = next(iter(dataloaders['train']))

out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # Utilizando um modelo já pré treinado. Resnet34

# %%
res_mod = models.resnet34(pretrained=True)

num_ftrs = res_mod.fc.in_features
res_mod.fc = nn.Linear(num_ftrs, 3)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %% [markdown]
# ## Visualização das camadas do modelo

# %%
for name, child in res_mod.named_children():
    print(name)
# Out:
# conv1
# bn1
# relu
# maxpool
# layer1
# layer2
# layer3
# layer4
# avgpool
# fc

# %% [markdown]
# # Aqui modificamos apenas as ultimas camadas do modelo para usar com as três classes de imagens
#
# depreciamos o LR por 0.1 a cada epoch.

# %%
res_mod = res_mod.to(device)
criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(res_mod.parameters(), lr=0.001, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# ## Definição das funções que treinam o modelo e visualização das predições.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=10):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        
        for phase in ['train', 'val']:
            if phase == 'train':
                scheduler.step()
                model.train()  
            else:
                model.eval()   

            current_loss = 0.0
            current_corrects = 0

            
            print('Iterating through data...')

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                
                optimizer.zero_grad()

                
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                
                current_loss += loss.item() * inputs.size(0)
                current_corrects += torch.sum(preds == labels.data)

            epoch_loss = current_loss / dataset_sizes[phase]
            epoch_acc = current_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))


            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_since = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_since // 60, time_since % 60))
    print('Best val Acc: {:4f}'.format(best_acc))


    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ## Visualização

# %%
def visualize_model(model, num_images=12):
    was_training = model.training
    model.eval()
    images_handeled = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_handeled += 1
                ax = plt.subplot(num_images//2, 2, images_handeled)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_handeled == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# # Treinamento do modelo e visualização da predição

# %%
base_model = train_model(res_mod, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=3)
visualize_model(base_model)
plt.show()
# Out:
# Epoch 0/2
# ----------
# Iterating through data...
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# ...

# %% [markdown]
# # Conclusão
#
# A utilização de animais muito distintos um dos outros pode ter contribuido para a alta acuracia do modelo. Porém a classificação das imagens foi um sucesso e a rede está treinada.
